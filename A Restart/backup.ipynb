# %%
{% extends 'base.html' %}

{% block content %}

{% for pizza in pizzas %}
    <h2> {{ pizza.name }} </h2>
    {% for pizzaTopping in pizza.toppings %}
        <h2> {{ pizzaTopping.name }} </h2>
    {% endfor %}
{% endfor %}

{% for pizza in pizzas %}
  <h1>{{ pizza.name }}</h1>
  <form action="" method="POST">
    <h2 class='pizzaName'>{{ pizza.name }}</h2>
    <h2>Select size:</h2>
    <div class="form-check">
      <input class="form-check-input" type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_small" value="Small">
      <label class="form-check-label" for="{{ pizza.id }}_small">
        Small
      </label>
    </div>
    <div class="form-check">
      <input class="form-check-input" type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_medium" value="Medium">
      <label class="form-check-label" for="{{ pizza.id }}_medium">
        Medium
      </label>
    </div>
    <div class="form-check">
      <input class="form-check-input" type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_large" value="Large">
      <label class="form-check-label" for="{{ pizza.id }}_large">
        Large
      </label>
    </div>
    <button type="submit" class="btn btn-primary" name="submit" value="buy_{{ pizza.id }}">Buy {{ pizza.name }}</button>
  </form>
{% endfor %}

<div id="selected-pizza"> {{ selected_pizza }} </div>

{% endblock content %}

# %%
{{ prices|selectattr('pizza', '==', pizza.name)|selectattr('size', '==', 'Small')|first.price }}

{{ prices|filter(pizza=pizza.name, size='Small')|first }}

# %%
is there anotehr way to change the background color based on what the  is_in_stock function returns :

{% for pizza in pizzas %}
  <div class="pizzaForm" id="pizzaForm-{{ pizza.id }}">
    <h2 class="pizza"> {{ pizza.name }} </h2>
    {% for pizzaTopping in pizza.toppings %}
        <h2> {{ pizzaTopping.name }} </h2>
    {% endfor %}
    {% set stock_level = is_in_stock(pizza.toppings, toppings) %}
    {% if stock_level == 'nothing' %}
      <style>
        #pizzaForm-{{ pizza.id }} {
          background-color: #ef0707;
        }
      </style>
    {% else %}
      <style>
        #pizzaForm-{{ pizza.id }} {
          background-color: #260462;
        }
      </style>
    {% endif %}
      <h1>Hoj {{ stock_level }}</h1>

{% endfor %}

# %%
{% for pizza in pizzas %}
  <div class="pizzaForm" id="pizzaForm-{{ pizza.id }}">
    <h2 class="pizza"> {{ pizza.name }} </h2>
    {% for pizzaTopping in pizza.toppings %}
      <h2> {{ pizzaTopping.name }} </h2>
    {% endfor %}
    {% set stock_level = is_in_stock(pizza.toppings, toppings) %}
    {% if stock_level == 'nothing' %}
      <script>
        document.querySelector("#pizzaForm-{{ pizza.id }}").style.backgroundColor = "#ef0707";
      </script>
    {% else %}
      <script>
        document.querySelector("#pizzaForm-{{ pizza.id }}").style.backgroundColor = "#260462";
      </script>
    {% endif %}
    <h1>Hoj {{ stock_level }}</h1>
  </div>
{% endfor %}

# %%
<button type="submit" name="submit" value="buy_{{ pizza.id }}">Buy {{ pizza.name }}</button>

# %%
{% extends "base.html" %}

{% block content %}

<form action="" method="POST">
    <label for="ingredient1">Ingredient 1:</label>
    <select name="ingredient1" id="ingredient1">
      {% for ingredient in toppingList %}
      <option value="{{ ingredient }}">{{ ingredient }}</option>
      {% endfor %}
    </select>
    <br>
  
    <label for="ingredient2">Ingredient 2:</label>
    <select name="ingredient2" id="ingredient2">
      {% for ingredient in toppingList %}
      <option value="{{ ingredient }}">{{ ingredient }}</option>
      {% endfor %}
    </select>
    <br>
  
    <label for="ingredient3">Ingredient 3:</label>
    <select name="ingredient3" id="ingredient3">
      {% for ingredient in toppingList %}
      <option value="{{ ingredient }}">{{ ingredient }}</option>
      {% endfor %}
    </select>
    <br>
  
    <label for="ingredient4">Ingredient 4:</label>
    <select name="ingredient4" id="ingredient4">
      {% for ingredient in toppingList %}
      <option value="{{ ingredient }}">{{ ingredient }}</option>
      {% endfor %}
    </select>
    <br>
  
    <label for="ingredient5">Ingredient 5:</label>
    <select name="ingredient5" id="ingredient5">
      {% for ingredient in toppingList %}
      <option value="{{ ingredient }}">{{ ingredient }}</option>
      {% endfor %}
    </select>
    <br>
  
    <button type="submit">Create Pizza</button>
  </form>
  


{% endblock content %}

# %%
  <script>
    var form = document.querySelector("#pizzaForm-{{ topping.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "red";
      form.disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.disabled = false; // enable the form
    }
  </script>
  <script>
    var form = document.querySelector("#pizzaForm-{{ topping.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "red";
      form.querySelector("button[type=submit]").disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.querySelector("button[type=submit]").disabled = false;
    }
  </script>

# %%
        if submit:
            pizza_id = submit.split('_')[1]
            pizza = Pizza.query.filter_by(id=pizza_id).first()
            pizza_name = pizza.name
            size = request.form.get(f"{pizza_id}_size")
            price = request.form.get(f"{pizza_id}_price_{size.lower()}")         
                     
            selected_pizza = f"You have selected {pizza_name} ({size}) {price}"                 
            
            flash(f"You have selected {pizza_name} ({size}) for {price}kr!", 'success')
            
            new_order = PizzaOrder(name=pizza_name, size=size, price=price)
            db.session.add(new_order)
            db.session.commit()

# %%
<!-- {% for pizza in pizzas %}
  <div class="pizza-container">
    <h2 class="pizza"> {{ pizza.name }} </h2>
    {% for pizzaTopping in pizza.toppings %}
        <h2> {{ pizzaTopping.name }} </h2>
    {% endfor %}
  </div>
{% endfor %} -->




{% for pizza in pizzas %}
  <h1>{{ pizza.name }}</h1>
  <h1>{{ pizza.toppings }}</h1>
  {% for topping in pizza.toppings %}
  <h2> OJOJ {{ topping.name }}</h2>
  {% endfor %}
  <p>Toppings: {{ pizza.toppings|map(attribute='name')|join(', ') }}</p>


  <form action="" method="POST" class="pizzaForm">
    <h2 class='pizzaName'>{{ pizza.name }}</h2>
    <p>Toppings: {{ pizza.toppings }} </p>
    <h2>Select size:</h2>
    <div class="size-container">

      <label for="{{ pizza.id }}_small">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_small" value="Small">
        Smal  
      {% for price in prices %}
        {% if price.pizza == pizza.name and price.size == 'Small' %}
          {{ price.price }}kr
        {% endif %}
      {% endfor %}
      </label>

      <label for="{{ pizza.id }}_medium">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_medium" value="Medium" checked>
        Medium
        {% for price in prices %}
        {% if price.pizza == pizza.name and price.size == 'Medium' %}
          {{ price.price }}kr
        {% endif %}
      {% endfor %}
      </label>

      <label for="{{ pizza.id }}_large">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_large" value="Large">
        Large
        {% for price in prices %}
        {% if price.pizza == pizza.name and price.size == 'Large' %}
          {{ price.price }}kr
        {% endif %}
      {% endfor %}
      </label>

    </div>
    <button type="submit" name="submit" value="buy_{{ pizza.id }}">Buy {{ pizza.name }}</button>
  </form>
{% endfor %}




<div id="selected-pizza"> {{ selected_pizza }} </div>

{% for price in prices %}
 <h2> {{price.pizza}} {{price.size}} {{price.price}} </h2>
 {% endfor %}


 {% for pizza in pizzas %}
 <h2> {{ pizza.name }} </h2>
 {% set stock_level = is_in_stock(pizza.toppings, toppings) %}
 <p>Stock Level: {{ stock_level }}</p>
{% endfor %}



<h1> Test Testing Testing</h1>




<p> Shit Shit Shit Shit </p>

# %%
<script>
  const pizzaForms = document.querySelectorAll('.pizzaForm');

  pizzaForms.forEach(pizzaForm => {
    pizzaForm.addEventListener('click', () => {
      pizzaForm.classList.toggle('is-active');
    });
  });
</script>

# %%
  <script>
    var form = document.querySelector("#pizzaForm-{{ pizza.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "#ff9999";
      form.disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.disabled = false; // enable the form
    }
  </script>
  <script>
    var form = document.querySelector("#pizzaForm-{{ pizza.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "red";
      form.querySelector("button[type=submit]").disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.querySelector("button[type=submit]").disabled = false;
    }
  </script>

# %%
{% extends 'base.html' %}

{% block content %}


{% with messages = get_flashed_messages(with_categories=true) %}
    {% if messages %}
        {% for category, message in messages %}
            <div class="alert alert-{{ category }}">
                {{ message }}
            </div>
        {% endfor %}
    {% endif %}
{% endwith %}

<br>

<h4 class='topping-container'>Update status with the radio buttons below:</h4>

{% for topping in toppings %}
<div class='topping-container'>
  <form action="" method="POST" class="" id="pizzaForm-{{ topping.id }}">
    <h3 class="pizzaName"> {{ topping.name }} </h3>
    <h3 class="pizzaName">Current inventory status: {{ topping.inventory }}</h2>
    <input type="hidden" name="topping_id" value="{{ topping.id }}">
    
    <div class="size-container">
      <label for="{{ topping.id }}_nothing">
        <input type="radio" name="{{ topping.id }}_size" id="{{ topping.id }}_nothing" value="nothing">
        Nothing  
      </label>

      <label for="{{ topping.id }}_little">
        <input type="radio" name="{{ topping.id }}_size" id="{{ topping.id }}_little" value="little">
        Little
      </label>

      <label for="{{ topping.id }}_modest">
        <input type="radio" name="{{ topping.id }}_size" id="{{ topping.id }}_modest" value="modest">
        Modest
      </label>

      <label for="{{ topping.id }}_plenty">
        <input type="radio" name="{{ topping.id }}_size" id="{{ topping.id }}_plenty" value="plenty">
        Plenty
      </label>

    </div>
    <button class="myMessage" type="submit" name="submit_pizza" value="buy_{{ topping.id }}" >Click to change topping inventory status</button>
  </form>
</div>

{% endfor %}


{% endblock content %}

# %%
{% extends 'base.html' %}

{% block content %}


<!-- <div id="selected-pizza"> {{ selected_pizza }} </div> -->

{% with messages = get_flashed_messages(with_categories=true) %}
    {% if messages %}
        {% for category, message in messages %}
            <div class="alert alert-{{ category }}">
                <!-- {{ message }} -->
                {{ message|safe }}
            </div>
        {% endfor %}
    {% endif %}
{% endwith %}


{% for pizza in pizzas %}
  <form action="" method="POST" class="pizzaForm" id="pizzaForm-{{ pizza.id }}">
    <h2 class="pizzaName"> {{ pizza.name }} </h2>
    <!-- {% for pizzaTopping in pizza.toppings %}
      <h2> {{ pizzaTopping.name }} </h2>
    {% endfor %} -->
    <h3>Toppings: {{ pizza.toppings|map(attribute='name')|join(', ') }}</h3>

    <h2>Select pizza size:</h2>
    <div class="size-container">
      <label for="{{ pizza.id }}_small">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_small" value="Small">
        Small  
        {% for price in prices %}
          {% if price.pizza == pizza.name and price.size == 'Small' %}
            {{ price.price }}kr
            <input type="hidden" name="{{ pizza.id }}_price_small" value="{{ price.price }}">
          {% endif %}
        {% endfor %}
      </label>

      <label for="{{ pizza.id }}_medium">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_medium" value="Medium" checked>
        Medium
        {% for price in prices %}
          {% if price.pizza == pizza.name and price.size == 'Medium' %}
            {{ price.price }}kr
            <input type="hidden" name="{{ pizza.id }}_price_medium" value="{{ price.price }}">
          {% endif %}
        {% endfor %}
      </label>

      <label for="{{ pizza.id }}_large">
        <input type="radio" name="{{ pizza.id }}_size" id="{{ pizza.id }}_large" value="Large">
        Large
        {% for price in prices %}
          {% if price.pizza == pizza.name and price.size == 'Large' %}
            {{ price.price }}kr
            <input type="hidden" name="{{ pizza.id }}_price_large" value="{{ price.price }}">
          {% endif %}
        {% endfor %}
      </label>
    </div>
    <!-- <button type="submit" name="submit_pizza" value="buy_{{ pizza.id }}">Buy {{ pizza.name }}</button> -->
    <button type="submit" name="submit_pizza" value="buy_{{ pizza.id }}" disabled>Buy {{ pizza.name }}</button>
  </form>


  <!-- <script>
    var form = document.querySelector("#pizzaForm-{{ pizza.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "#ff9999";
      form.style.backgroundColor = "#ff9999";

      form.disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.disabled = false; // enable the form
    }
  </script> -->

  <script>
    var form = document.querySelector("#pizzaForm-{{ pizza.id }}");
    var stock_level = "{{ is_in_stock(pizza.toppings, toppings) }}";
    if (stock_level == 'nothing') {
      form.style.backgroundColor = "#ff9999";

      form.querySelector("button[type=submit]").disabled = true; // disable the form
    } else {
      form.style.backgroundColor = "#2b7bd4";
      form.querySelector("button[type=submit]").disabled = false;
    }
  </script>

{% endfor %}

<script>
  const pizzaForms = document.querySelectorAll('.pizzaForm');
  let lastClickedPizzaForm = null;
  
  pizzaForms.forEach(pizzaForm => {
    pizzaForm.addEventListener('click', () => {
      if (lastClickedPizzaForm !== null && lastClickedPizzaForm !== pizzaForm) {
        lastClickedPizzaForm.classList.remove('is-active');
      }
      pizzaForm.classList.toggle('is-active');
      lastClickedPizzaForm = pizzaForm;
    });
  });
</script>




{% endblock content %}


{% with messages = get_flashed_messages(with_categories=true) %}
    {% if messages %}
        {% for category, message in messages %}
            <div class="alert alert-{{ category }}">
                {{ message }}
            </div>
        {% endfor %}
    {% endif %}
{% endwith %}


{% block sidebar %}
  <p class="myMessage">Your current order below:</p>
{% for order in orders %}
  <div class='list-container'>
    <h2> {{order}} </h2>
  </div>
{% endfor %}
<br>
<form action="{{ url_for('views.home') }}" method="POST">
  <button class="myMessage" type="submit" name="makeOrder" value="makeOrder">Click to send order! Total current price: {{ current_price }} </button>
</form>

{% endblock sidebar %}
